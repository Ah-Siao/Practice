# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Reshape, Conv2DTranspose, Add, Conv2D, MaxPool2D, Dense, Flatten, InputLayer, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
(x_train,_),(x_test,_)=tf.keras.datasets.mnist.load_data()

# %%
# add one more dimension and make the number between 0-1 (divided by 255)
x_train=np.expand_dims(x_train,-1).astype('float32')/255
x_test=np.expand_dims(x_test,-1).astype('float32')/255

# %%
x_train_dataset=tf.data.Dataset.from_tensor_slices(x_train)

# %%
# let's shuffle and batch our dataset
batch_size=64
buffer_size=1000
train_dataset=x_train_dataset.shuffle(buffer_size=batch_size*buffer_size, reshuffle_each_iteration=True).batch(batch_size,drop_remainder=True).prefetch(tf.data.AUTOTUNE)

# %%
first_batch=iter(train_dataset).get_next()
k=1
while k<65:
    ax=plt.subplot(8,8,k)
    plt.imshow(first_batch[k-1])
    plt.axis('off')
    k+=1

# %% [markdown]
# ### Encoder

# %%
class Sampling(Layer):
    def call(self,inputs):
        mean,log_var=inputs
        return mean + tf.math.exp(0.5*log_var)*tf.random.normal(shape=(tf.shape(mean)[0],tf.shape(mean)[1]))

# %%
latent_dim=5

# %%
encoder_inputs=Input(shape=(28,28,1))
x=Conv2D(32,3,activation='relu',strides=2,padding='same')(encoder_inputs)
x=Conv2D(64,3,activation='relu',strides=2,padding='same')(x)
x=Flatten()(x)
x=Dense(16,activation='relu')(x)
mean=Dense(latent_dim,)(x)
log_var=Dense(latent_dim,)(x)
z=Sampling()([mean,log_var])
encoder_model=Model(encoder_inputs,[z,mean,log_var],name='encoder')
encoder_model.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 32)   320         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 64)     18496       conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3136)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           50192       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 5)            85          dense_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 5)            85          dense_4[0][0]
# __________________________________________________________________________________________________
# sampling_1 (Sampling)           (None, 5)            0           dense_5[0][0]
#                                                                  dense_6[0][0]
# ==================================================================================================
# Total params: 69,178
# Trainable params: 69,178
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Decoder

# %%
latent_inputs=Input(shape=(latent_dim,))
x=Dense(7*7*64,activation='relu')(latent_inputs)
x=Reshape((7,7,64))(x)
x=Conv2DTranspose(64,3,activation='relu',strides=2,padding='same')(x)
x=Conv2DTranspose(32,3,activation='relu',strides=2,padding='same')(x)
decoder_outputs=Conv2DTranspose(1,3,activation='sigmoid',padding='same')(x)
decoder_model=Model(latent_inputs,decoder_outputs,name='decoder')
decoder_model.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 5)]               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3136)              18816
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 28, 28, 32)        18464
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 28, 28, 1)         289
# =================================================================
# Total params: 74,497
# Trainable params: 74,497
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Overall VAE Model

# %%
vae_input=Input(shape=(28,28,1),name='vae_input')
z,_,_=encoder_model(vae_input)
output=decoder_model(z)
vae=Model(vae_input,output,name='vae')
vae.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vae_input (InputLayer)       [(None, 28, 28, 1)]       0
# _________________________________________________________________
# encoder (Functional)         [(None, 5), (None, 5), (N 69178
# _________________________________________________________________
# decoder (Functional)         (None, 28, 28, 1)         74497
# =================================================================
# Total params: 143,675
# Trainable params: 143,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x22bcb6e6be0>,
#  <keras.engine.functional.Functional at 0x22890e05b20>,
#  <keras.engine.functional.Functional at 0x22890e25760>]

# %%
def custom_loss(y_true,y_pred,mean,log_var):
    loss_recons=tf.reduce_mean(tf.reduce_sum(tf.keras.losses.binary_crossentropy(y_true,y_pred),axis=(1,2)))
    loss_reg=tf.reduce_mean(tf.reduce_sum(-0.5*(log_var+1-tf.math.square(mean)-tf.math.exp(log_var)),axis=1))
    return loss_recons+loss_reg

# %%
OPTIMIZER=Adam(learning_rate=1e-3)

# %%
@tf.function
def training_block(x_batch):
    with tf.GradientTape() as recorder:
        z,mean,log_var=encoder_model(x_batch)
        y_pred=decoder_model(z)
        y_true=x_batch
        loss=custom_loss(y_true,y_pred,mean,log_var)
    partial_derivatives=recorder.gradient(loss,vae.trainable_weights)
    OPTIMIZER.apply_gradients(zip(partial_derivatives,vae.trainable_weights))
    return loss

# %%
def neuralearn(epochs):
    for epoch in range(1,epochs+1):
        print(f'Training starts for epochs number {epoch}')
        for step,x_batch in enumerate(train_dataset):
            loss=training_block(x_batch)
        print('Training loss is:',loss)
    print('Training Complete!')

# %%
neuralearn(50)
# Out:
# Training starts for epochs number 1
# Training loss is: tf.Tensor(195.3221, shape=(), dtype=float32)
# Training starts for epochs number 2
# Training loss is: tf.Tensor(185.22162, shape=(), dtype=float32)
# Training starts for epochs number 3
# Training loss is: tf.Tensor(174.21382, shape=(), dtype=float32)
# Training starts for epochs number 4
# Training loss is: tf.Tensor(180.7513, shape=(), dtype=float32)
# Training starts for epochs number 5
# Training loss is: tf.Tensor(175.44144, shape=(), dtype=float32)
# Training starts for epochs number 6
# Training loss is: tf.Tensor(177.82613, shape=(), dtype=float32)
# Training starts for epochs number 7
# Training loss is: tf.Tensor(166.61514, shape=(), dtype=float32)
# Training starts for epochs number 8
# Training loss is: tf.Tensor(182.09448, shape=(), dtype=float32)
# Training starts for epochs number 9
# Training loss is: tf.Tensor(174.4289, shape=(), dtype=float32)
# Training starts for epochs number 10
# Training loss is: tf.Tensor(175.58868, shape=(), dtype=float32)
# Training starts for epochs number 11
# Training loss is: tf.Tensor(157.3622, shape=(), dtype=float32)
# Training starts for epochs number 12
# Training loss is: tf.Tensor(170.66159, shape=(), dtype=float32)
# Training starts for epochs number 13
# Training loss is: tf.Tensor(166.38011, shape=(), dtype=float32)
# Training starts for epochs number 14
# Training loss is: tf.Tensor(184.16153, shape=(), dtype=float32)
# Training starts for epochs number 15
# Training loss is: tf.Tensor(180.75403, shape=(), dtype=float32)
# Training starts for epochs number 16
# Training loss is: tf.Tensor(172.98878, shape=(), dtype=float32)
# Training starts for epochs number 17
# Training loss is: tf.Tensor(169.7498, shape=(), dtype=float32)
# Training starts for epochs number 18
# Training loss is: tf.Tensor(173.96758, shape=(), dtype=float32)
# Training starts for epochs number 19
# Training loss is: tf.Tensor(155.9609, shape=(), dtype=float32)
# Training starts for epochs number 20
# Training loss is: tf.Tensor(156.1267, shape=(), dtype=float32)
# Training starts for epochs number 21
# Training loss is: tf.Tensor(168.97484, shape=(), dtype=float32)
# Training starts for epochs number 22
# Training loss is: tf.Tensor(174.55746, shape=(), dtype=float32)
# Training starts for epochs number 23
# Training loss is: tf.Tensor(175.89958, shape=(), dtype=float32)
# Training starts for epochs number 24
# Training loss is: tf.Tensor(170.44008, shape=(), dtype=float32)
# Training starts for epochs number 25
# Training loss is: tf.Tensor(180.34378, shape=(), dtype=float32)
# Training starts for epochs number 26
# Training loss is: tf.Tensor(173.12053, shape=(), dtype=float32)
# Training starts for epochs number 27
# Training loss is: tf.Tensor(167.2368, shape=(), dtype=float32)
# Training starts for epochs number 28
# Training loss is: tf.Tensor(176.41463, shape=(), dtype=float32)
# Training starts for epochs number 29
# Training loss is: tf.Tensor(184.65665, shape=(), dtype=float32)
# Training starts for epochs number 30
# Training loss is: tf.Tensor(172.15453, shape=(), dtype=float32)
# Training starts for epochs number 31
# Training loss is: tf.Tensor(170.88875, shape=(), dtype=float32)
# Training starts for epochs number 32
# Training loss is: tf.Tensor(170.0192, shape=(), dtype=float32)
# Training starts for epochs number 33
# Training loss is: tf.Tensor(174.61136, shape=(), dtype=float32)
# Training starts for epochs number 34
# Training loss is: tf.Tensor(179.2694, shape=(), dtype=float32)
# Training starts for epochs number 35
# Training loss is: tf.Tensor(175.38673, shape=(), dtype=float32)
# Training starts for epochs number 36
# Training loss is: tf.Tensor(166.08292, shape=(), dtype=float32)
# Training starts for epochs number 37
# Training loss is: tf.Tensor(161.79385, shape=(), dtype=float32)
# Training starts for epochs number 38
# Training loss is: tf.Tensor(168.73193, shape=(), dtype=float32)
# Training starts for epochs number 39
# Training loss is: tf.Tensor(162.5931, shape=(), dtype=float32)
# Training starts for epochs number 40
# Training loss is: tf.Tensor(173.28438, shape=(), dtype=float32)
# Training starts for epochs number 41
# Training loss is: tf.Tensor(157.89899, shape=(), dtype=float32)
# Training starts for epochs number 42
# Training loss is: tf.Tensor(159.45549, shape=(), dtype=float32)
# Training starts for epochs number 43
# Training loss is: tf.Tensor(180.16252, shape=(), dtype=float32)
# Training starts for epochs number 44
# Training loss is: tf.Tensor(167.96767, shape=(), dtype=float32)
# Training starts for epochs number 45
# Training loss is: tf.Tensor(168.50606, shape=(), dtype=float32)
# Training starts for epochs number 46
# Training loss is: tf.Tensor(168.7209, shape=(), dtype=float32)
# Training starts for epochs number 47
# Training loss is: tf.Tensor(171.908, shape=(), dtype=float32)
# Training starts for epochs number 48
# Training loss is: tf.Tensor(159.22856, shape=(), dtype=float32)
# Training starts for epochs number 49
# Training loss is: tf.Tensor(180.37633, shape=(), dtype=float32)
# Training starts for epochs number 50
# Training loss is: tf.Tensor(173.43623, shape=(), dtype=float32)
# Training Complete!

# %%
test_dataset=tf.data.Dataset.from_tensor_slices(x_test).batch(64).prefetch(tf.data.AUTOTUNE)
first_batch=iter(test_dataset).get_next()
# original images
k=1
while k<65:
    plt.subplot(8,8,k)
    plt.imshow(first_batch[k-1])
    plt.axis('off')
    k+=1
plt.suptitle('origin')
plt.savefig('vae_origin.png')

# %%
predicted_1batch=vae.predict(first_batch)
k=1
while k<65:
    plt.subplot(8,8,k)
    plt.imshow(predicted_1batch[k-1])
    plt.axis('off')
    k+=1
plt.suptitle('after VAE')
plt.savefig('vae_result.png')

# %%
ori=Image.open('vae_origin.png')
after=Image.open('vae_result.png')
images=[ori,after]
ori.save('vae_compare.gif',format='GIF',append_images=images,save_all=True,duration=300,loop=0)

# %%
## of course we can use the decoder (vae.layers[2]) as generative model 
# let's generate image from random number sampling from normal distribution
k=1
input_shape=(1,latent_dim)
while k<65:
    plt.subplot(8,8,k)
    input=tf.random.normal(input_shape)
    out=vae.layers[2].predict(input)[0,...]
    plt.imshow(out)
    plt.axis('off')
    k+=1

# %%
def euclidean_distance(v1,v2):
    return np.sqrt(np.sum((v1 - v2)**2))

# %%
from itertools import combinations

(x_train,y_train),_=tf.keras.datasets.mnist.load_data()
x_train=np.expand_dims(x_train,-1).astype('float32')/255
z,_,_=vae.layers[1].predict(x_train)

a=list(range(latent_dim))
dist_table={}
for i in combinations(a,2):
    idx1,idx2=i
    dist=euclidean_distance(z[:,idx1],z[:,idx2])
    dist_table[f'{idx1}_{idx2}']=dist
[v1,v2]=max(dist_table).split('_')

plt.figure(figsize=(5,3))
plt.scatter(z[:,int(v1)],z[:,int(v2)],c=y_train,s=1)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Save and load the model

# %%
tf.saved_model.save(vae,'vae_model')
# Out:
# INFO:tensorflow:Assets written to: vae_model\assets

# %%
vae_saved_model=tf.saved_model.load('vae_model')

# %%
predicted_1batch=vae_saved_model(first_batch)
k=1
while k<65:
    plt.subplot(8,8,k)
    plt.imshow(predicted_1batch[k-1])
    plt.axis('off')
    k+=1
plt.suptitle('after loaded_vae')
# plt.savefig('loaded_vae_result.png')
# Out:
# Text(0.5, 0.98, 'after loaded_vae')
